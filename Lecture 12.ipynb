# %% [markdown]
# <center>
#     <h1 style="color:blue"> YSU MMF, Python, Spring 2021 </h1>
#     <h2 style="color:blue"> Lecture 12 </h2>
# </center>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - Using matplotlib.pyplot, plot the graph of the `sin` and `cos` functions on $[0,\pi]$

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
x = np.linspace(0, np.pi, 100)
y = np.sin(x)
z = np.cos(x)      
plt.plot(x, y, label="sinx")    # plt.plot(x, y, x, z)  
plt.plot(x, z, label="cosx")
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="387.77778805038105">

# %% [markdown]
# - Calculate the approximate value of the
# $$
# \int_0^1 \sin(x) dx,
# $$
# using the `midpoint rectangles` rule and `trapezoids` tule

# %%
def SinInt_Midpoint(a, b, n=10):
    x = np.linspace(a, b, n + 1)
    h = (b - a) / n
    t = np.arange(a + h / 2, b, h)
    Sum = np.sum(np.sin(t) * h)
    
    true_value = np.cos(a) - np.cos(b)
    error = np.abs(Sum - true_value)
    return Sum, error

# %%
SinInt_Midpoint(a=0, b=2, n=10000)
# Out:
# (1.4161468389073875, 2.360245110466508e-09)

# %%
############ test ###################

# %%
n = 10
a = 0
b = 1

x = np.linspace(0, 1, n + 1)
h = (b - a) / n

# %%
t = np.arange(a + h / 2, b, h)
Sum = np.sum(np.sin(t) * h)
Sum
# Out:
# 0.4598892907185182

# %%
sum_ = 0
for i in range(n):
    sum_ += np.sin((x[i] + x[i + 1]) / 2) * h
sum_
# Out:
# 0.45988929071851814

# %%
true_value = 1 - np.cos(1)
true_value
# Out:
# 0.45969769413186023

# %%
error = abs(sum_ - true_value)
error
# Out:
# 0.00019159658665790502

# %%
#####################################
